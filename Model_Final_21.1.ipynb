# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
import threading
import queue
from pymodbus.client import ModbusTcpClient

# %%
cam = 2
fps = 240 #Maximum achivable was 163.06

model_version = "my_model_20.0.keras"
max_frames = 10  # Number of frames to evaluate

image_path = "no_bottle.jpg"
frame_buffer = []
frame_queue = queue.Queue(maxsize=10)

Im_Width = 128
Im_Height = 128

#crop
x = 120
y = 0
w = 400
h = 200

max_brightness = 180

stop_event = threading.Event()

coil_address = 1536 #ModBus Y0
PLC_IP = "192.168.1.111"  #PLC's IP address
PLC_PORT = 502           # Default Modbus TCP port

# %%
def modbus(PLC_IP, PLC_PORT):

    # Create Modbus client
    client = ModbusTcpClient(PLC_IP, port=PLC_PORT)

    # Connect to the PLC
    if client.connect():
        print("Connection successful")
    else:
        print("Failed to connect to PLC")
    return client

# %%
def PLC(client, coil_address,value):
    write_result = client.write_coil(address=coil_address, value=value)  # Write 'True' to turn ON
    if write_result.isError():
        print("Write Error:", write_result)
    else:
        print(f"Output Y0 turned ON (Coil {coil_address})")

# %%
def crop_image(frame, x, y, w, h):
    return frame[y:y+h, x:x+w]

# %%
def measure_brightness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
    brightness = np.mean(gray)
    return brightness

# %%
def measure_edge_richness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    edges = cv2.Canny(gray, 100, 200)  # Apply Canny edge detection
    edge_richness = np.sum(edges)  # Sum of edge pixel intensities
    return edge_richness

# %%
def select_best_frame(frame_buffer, x, y, w, h, max_brightness):

    best_frame = None
    highest_brightness = 0
    highest_edge_richness = 400000

    for frame in frame_buffer:

        #Crop
        cropped_frame = crop_image(frame, x, y, w, h)

        # Measure brightness
        brightness = measure_brightness(cropped_frame)

        if brightness > max_brightness :
            # Update the best frame if this one is better
            if brightness > highest_brightness:
                highest_brightness = brightness
                best_frame = frame  # Save the frame as the best frame
        
        elif brightness > 150 and brightness < 181:
            # Apply edge detection
            edge_richness = measure_edge_richness(cropped_frame)
            # Update the best frame if this one is better
            if edge_richness > highest_edge_richness:
                highest_edge_richness = edge_richness
                best_frame = frame  # Save the cropped frame as the best frame


    return best_frame  # Returns None if no frames meet the threshold

# %%
def process_frame(frame, target_size):

    # Resize the frame to the target size
    resized_frame = cv2.resize(frame, target_size)

    # Normalize pixel values to [0, 1]
    normalized_frame = resized_frame / 255.0

    # Convert to NumPy array and add batch dimension
    frame_array = img_to_array(normalized_frame)
    frame_array = np.expand_dims(frame_array, axis=0)  # Shape: (1, height, width, channels)

    return frame_array

# %%
def predict_frame(frame, model, target_size):

    # Preprocess the frame
    frame_array = process_frame(frame, target_size)

   # Make a prediction
    prediction = model.predict(frame_array)[0][0]  # Get the confidence score
    print(f"Raw Prediction: {prediction}")

    # Interpret the prediction
    if prediction > 0.5:
        PLC(client, coil_address,False)
        return "Non-Defective", prediction      
        
    else:
        PLC(client, coil_address,True)
        return "Defective", prediction

# %%
def capture(cam, fps, frame_buffer, frame_queue, max_frames, stop_event):
    
    cap = cv2.VideoCapture(cam)  # Open webcam
    cap.set(cv2.CAP_PROP_FPS, fps)  # Set the desired FPS

    while not stop_event.is_set():
        if not cap.isOpened():
            print("Error: Cannot open camera.")
            return

        while not stop_event.is_set():
            ret, frame = cap.read()
            if not ret:
                print("Failed to capture frame. Exiting...")
                break

            frame_buffer.append(frame)

            # Yield the buffer when it's full
            if len(frame_buffer) == max_frames:
                frame_queue.put(frame_buffer.copy())  # Add a copy of the buffer
                frame_buffer.clear()  # Clear the buffer for the next batch

    cap.release()

# %%
def runModel(model_version, frame_queue, x, y, w, h, max_brightness, stop_event, target_size=(Im_Width, Im_Height)):

    # Load the model
    print("Loading model...") 
    model = load_model(model_version)
    print("Model loaded successfully.")
    
    while True:
        frame_buffer = frame_queue.get()
        best_frame = select_best_frame(frame_buffer, x, y, w, h, max_brightness)
        # Process and predict
        if best_frame is not None:
            feedback, confidence = predict_frame(best_frame, model, target_size)
            
            prob = abs(round(confidence,2)- 0.5)*200
            print(f"Prediction: {feedback} (Confidence: {prob:.2f})")

            # Display feedback on the frame
            cv2.putText(best_frame, f"Prediction: {feedback}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(best_frame, f"Confidence: {prob:.0f}", (10, 60),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

            # Display the best frame
            cv2.imshow("Best Frame", best_frame)

        else:
            # Load and display the "no-bottle" image in the same window
            PLC(client, coil_address,False)
            image = cv2.imread(image_path)
            cv2.putText(image, "No Bottle!", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.imshow("Best Frame", image)

        # Exit on 'ESC' key
        if cv2.waitKey(1) & 0xFF == 27:
            stop_event.set()
            break

    cv2.destroyAllWindows()

# %%
capture_thread = threading.Thread(target=capture, args=(cam, fps, frame_buffer, frame_queue, max_frames, stop_event))
runModel_thread = threading.Thread(target=runModel, args=(model_version, frame_queue, x, y, w, h, max_brightness, stop_event))

# %%
if __name__ == "__main__":

    client = modbus(PLC_IP, PLC_PORT)

    # Start the threads
    capture_thread.start()
    runModel_thread.start()

    # Wait for threads to complete
    capture_thread.join()
    #frame_queue.join()
    runModel_thread.join()
# Out:
# Connection successful
# Loading model...
# Model loaded successfully.
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# Raw Prediction: 0.9966751933097839
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9924510717391968
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 98.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.030176354572176933
# Output Y0 turned ON (Coil 1536)
# Prediction: Defective (Confidence: 94.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9970791339874268
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9973090291023254
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9991136789321899
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9932106137275696
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 98.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.589640736579895
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 18.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.039928682148456573
# Output Y0 turned ON (Coil 1536)
# Prediction: Defective (Confidence: 92.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.09584297239780426
# Output Y0 turned ON (Coil 1536)
# Prediction: Defective (Confidence: 80.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.11266603320837021
# Output Y0 turned ON (Coil 1536)
# Prediction: Defective (Confidence: 78.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.23930731415748596
# Output Y0 turned ON (Coil 1536)
# Prediction: Defective (Confidence: 52.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.8857835531234741
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 78.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9957724809646606
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9996182322502136
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9704189896583557
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 94.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9941951632499695
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 98.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Raw Prediction: 0.9846946001052856
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 96.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9884033799171448
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 98.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9888856410980225
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 98.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# ...
# Raw Prediction: 0.1324768364429474
# Output Y0 turned ON (Coil 1536)
# Prediction: Defective (Confidence: 74.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.00024333536566700786
# Output Y0 turned ON (Coil 1536)
# Prediction: Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 1.5701708662163583e-06
# Output Y0 turned ON (Coil 1536)
# Prediction: Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 7.328475959411662e-08
# Output Y0 turned ON (Coil 1536)
# Prediction: Defective (Confidence: 100.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9997203946113586
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9607541561126709
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 92.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9875430464744568
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 98.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.04124445468187332
# Output Y0 turned ON (Coil 1536)
# Prediction: Defective (Confidence: 92.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9699282646179199
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 94.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Raw Prediction: 0.9781277775764465
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 96.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9910010695457458
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 98.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9994751214981079
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9994183778762817
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Raw Prediction: 0.9524179697036743
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 90.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9775305986404419
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 96.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9955935478210449
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
