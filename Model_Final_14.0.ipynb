# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
import threading
import queue
#import time

# %%
cam = 0
fps = 240 #Maximum achivable was 163.06

model_version = "my_model_20.0.keras"
max_frames = 3  # Number of frames to evaluate

image_path = "no_bottle.jpg"
frame_buffer = []
frame_queue = queue.Queue(maxsize=20)

Im_Width = 128
Im_Height = 128

#crop
x = 120
y = 0
w = 400
h = 200

max_brightness = 175
#max_edgeRichness = 

#run = True
stop_event = threading.Event()

# %%
def crop_image(frame, x, y, w, h):
    return frame[y:y+h, x:x+w]

# %%
def measure_brightness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
    brightness = np.mean(gray)
    return brightness

# %%
def measure_edge_richness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    edges = cv2.Canny(gray, 200, 400)  # Apply Canny edge detection
    edge_richness = np.sum(edges)  # Sum of edge pixel intensities
    return edge_richness

# %%
def select_best_frame(frame_buffer, x, y, w, h, max_brightness):

    best_frame = None
    highest_brightness = 0
    highest_edge_richness = 0

    for frame in frame_buffer:

        #Crop
        cropped_frame = crop_image(frame, x, y, w, h)

        # Measure brightness
        brightness = measure_brightness(cropped_frame)

        if brightness > max_brightness :
            # Update the best frame if this one is better
            if brightness > highest_brightness:
                highest_brightness = brightness
                best_frame = frame  # Save the frame as the best frame
        
        elif brightness > 150 and brightness < 176:
            # Apply edge detection
            edge_richness = measure_edge_richness(cropped_frame)
            # Update the best frame if this one is better
            if edge_richness > highest_edge_richness:
                highest_edge_richness = edge_richness
                best_frame = frame  # Save the cropped frame as the best frame


    return best_frame  # Returns None if no frames meet the threshold

# %%
def process_frame(frame, target_size):

    # Resize the frame to the target size
    resized_frame = cv2.resize(frame, target_size)

    # Normalize pixel values to [0, 1]
    normalized_frame = resized_frame / 255.0

    # Convert to NumPy array and add batch dimension
    frame_array = img_to_array(normalized_frame)
    frame_array = np.expand_dims(frame_array, axis=0)  # Shape: (1, height, width, channels)

    return frame_array

# %%
def predict_frame(frame, model, target_size):

    # Preprocess the frame
    frame_array = process_frame(frame, target_size)

   # Make a prediction
    prediction = model.predict(frame_array)[0][0]  # Get the confidence score
    print(f"Raw Prediction: {prediction}")

    # Interpret the prediction
    if prediction > 0.5:
        return "Non-Defective", prediction       
        
    else:
        return "Defective", prediction

# %%
def capture(cam, fps, frame_buffer, frame_queue, max_frames, stop_event):
    
    cap = cv2.VideoCapture(cam)  # Open webcam
    cap.set(cv2.CAP_PROP_FPS, fps)  # Set the desired FPS

    while not stop_event.is_set():
        if not cap.isOpened():
            print("Error: Cannot open camera.")
            return

        while not stop_event.is_set():
            ret, frame = cap.read()
            if not ret:
                print("Failed to capture frame. Exiting...")
                break

            frame_buffer.append(frame)

            # Yield the buffer when it's full
            if len(frame_buffer) == max_frames:
                frame_queue.put(frame_buffer.copy())  # Add a copy of the buffer
                frame_buffer.clear()  # Clear the buffer for the next batch

    cap.release()

# %%
# import cv2
# import threading
# import queue
# import time

# def capture_frames(cam, fps, frame_queue, buffer_size=30):
#     """
#     Captures frames from the camera and stores them in a queue for processing.
    
#     Args:
#         cam (int): Camera index.
#         fps (int): Frames per second.
#         frame_queue (queue.Queue): Queue to store frame buffers.
#         buffer_size (int): Number of frames per buffer.
#     """
#     cap = cv2.VideoCapture(cam)  # Open webcam
#     cap.set(cv2.CAP_PROP_FPS, fps)  # Set FPS

#     if not cap.isOpened():
#         print("Error: Cannot open camera.")
#         return

#     frame_buffer = []

#     while True:
#         ret, frame = cap.read()
#         if not ret:
#             print("Failed to capture frame. Exiting...")
#             break

#         frame_buffer.append(frame)

#         # Add the buffer to the queue when full
#         if len(frame_buffer) == buffer_size:
#             frame_queue.put(frame_buffer.copy())  # Add a copy of the buffer
#             frame_buffer.clear()  # Clear the buffer for the next batch

#     cap.release()

# def process_frames(frame_queue):
#     """
#     Processes frame buffers retrieved from the queue.
    
#     Args:
#         frame_queue (queue.Queue): Queue to retrieve frame buffers from.
#     """
#     while True:
#         try:
#             # Get a buffer from the queue
#             frame_buffer = frame_queue.get(timeout=5)  # Wait for buffer (5 sec timeout)
#             print(f"Processing buffer with {len(frame_buffer)} frames")
            
#             # Simulate processing time
#             time.sleep(1)

#         except queue.Empty:
#             print("No buffers left to process. Exiting...")
#             break

# if __name__ == "__main__":
#     cam = 0  # Default camera index
#     fps = 30  # Desired FPS
#     buffer_size = 30  # Number of frames per buffer
#     frame_queue = queue.Queue(maxsize=10)  # Queue with a maximum of 10 buffers

#     # Create threads
#     capture_thread = threading.Thread(target=capture_frames, args=(cam, fps, frame_queue, buffer_size))
#     processing_thread = threading.Thread(target=process_frames, args=(frame_queue,))

#     # Start threads
#     capture_thread.start()
#     processing_thread.start()

#     # Wait for threads to complete
#     capture_thread.join()
#     processing_thread.join()

#     print("All tasks completed.")

# %%
def runModel(model_version, frame_queue, x, y, w, h, max_brightness, stop_event, target_size=(Im_Width, Im_Height)):

    # Load the model
    print("Loading model...") 
    model = load_model(model_version)
    print("Model loaded successfully.")
    
    while True:
        frame_buffer = frame_queue.get()
        best_frame = select_best_frame(frame_buffer, x, y, w, h, max_brightness)
        # Process and predict
        if best_frame is not None:
            feedback, confidence = predict_frame(best_frame, model, target_size)
            print(f"Prediction: {feedback} (Confidence: {confidence:.2f})")

            prob = abs(round(confidence,2)- 0.5)*200

            # Display feedback on the frame
            cv2.putText(best_frame, f"Prediction: {feedback}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(best_frame, f"Confidence: {prob:.0f}", (10, 60),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

            # Display the best frame
            cv2.imshow("Best Frame", best_frame)

        else:
            # Load and display the "no-bottle" image in the same window
            image = cv2.imread(image_path)
            cv2.putText(image, "No Bottle!", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.imshow("Best Frame", image)

        # Exit on 'ESC' key
        if cv2.waitKey(1) & 0xFF == 27:
            #run = False
            stop_event.set()
            break

    cv2.destroyAllWindows()
    #return run

# %%
capture_thread = threading.Thread(target=capture, args=(cam, fps, frame_buffer, frame_queue, max_frames, stop_event))
runModel_thread = threading.Thread(target=runModel, args=(model_version, frame_queue, x, y, w, h, max_brightness, stop_event))

# %%
if __name__ == "__main__":

    # Start the threads
    capture_thread.start()
    runModel_thread.start()

    # Wait for threads to complete
    capture_thread.join()
    #frame_queue.join()
    runModel_thread.join()
# Out:
# Loading model...
# Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 822ms/step
# Raw Prediction: 0.0012344869319349527
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0016159956576302648
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.0014480955433100462
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.0019390281522646546
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.0021176955197006464
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.0020083533599972725
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.0019190008752048016
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0016719818813726306
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.0015620674239471555
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.001516022370196879
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.0023127361200749874
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.0027195510920137167
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.0025341869331896305
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.0032092961482703686
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.003091047750785947
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.0035060164518654346
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.003575534326955676
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.003630709368735552
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.0035408593248575926
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.004220274277031422
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.004067347384989262
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.004313301295042038
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.004313301295042038
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.0039025077130645514
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.003670573001727462
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.004554396495223045
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.003789577865973115
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.004887981805950403
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.004802295006811619
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.0035044741816818714
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.00401125755161047
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.004033721052110195
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.004225993063300848
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.0038164674770087004
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.0035421126522123814
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.003081083996221423
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.0029392193537205458
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0026211494114249945
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.0024056825786828995
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0035336168948560953
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.0028477669693529606
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.003210129216313362
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.0040575312450528145
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.0040575312450528145
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Raw Prediction: 0.0032196608372032642
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.0036244860384613276
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.003408386604860425
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.003076864406466484
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.002797986613586545
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.002527569653466344
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.0020958827808499336
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0023305744398385286
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0024114579427987337
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Raw Prediction: 0.0027202232740819454
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.003028985345736146
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.0028504368383437395
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Raw Prediction: 0.0028504368383437395
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.0031629842706024647
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.0031629842706024647
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.012424170970916748
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Raw Prediction: 0.009640460833907127
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.021848198026418686
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.021848198026418686
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.0063784425146877766
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.004734141752123833
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.005186507012695074
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.00814738404005766
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.012185457162559032
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.007111556828022003
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.007612220942974091
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.006547515280544758
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.005378548987209797
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Raw Prediction: 0.004279191605746746
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0022054086439311504
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.003577209310606122
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0030987304635345936
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.0018914848333224654
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.003024536184966564
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0010276735993102193
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.0012752790935337543
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.0009619307238608599
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0020389461424201727
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.0013860493199899793
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0012213937006890774
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.00011052724585169926
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.0006497933645732701
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.0007693952647969127
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Raw Prediction: 0.003077711444348097
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.002024316694587469
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.001029169769026339
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.00018442110740579665
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.00018442110740579665
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.001941215363331139
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.0339585542678833
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.030443264171481133
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.03897415101528168
# Prediction: Defective (Confidence: 0.04)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.0008831968880258501
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 1.8499276848160662e-05
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Raw Prediction: 6.893577392474981e-06
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 4.459840783965774e-05
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.009920042008161545
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.010089620016515255
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.015425312332808971
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.011644475162029266
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.00791153497993946
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.035561271011829376
# Prediction: Defective (Confidence: 0.04)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.02050619013607502
# Prediction: Defective (Confidence: 0.02)
