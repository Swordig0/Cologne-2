# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
import threading
import queue
import time
from pymodbus.client import ModbusTcpClient

# %%
cam = 2
fps = 240 #Maximum achievable was 163.06

model_version = "my_model_20.0.keras"
max_frames = 10  # Number of frames to evaluate

image_path = "no_bottle.jpg"
frame_buffer = []
raw_frame_queue = queue.Queue(maxsize=20)  # Queue for raw frames
processed_frame_queue = queue.Queue(maxsize=10)  # Queue for processed frames

Im_Width = 128
Im_Height = 128

#crop
x = 120
y = 0
w = 400
h = 200

a = 290
b = 110
c = 100
d = 100

max_brightness = 175

stop_event = threading.Event()

coil_address = 1536 #ModBus Y0
PLC_IP = "192.168.1.111"  #PLC's IP address
PLC_PORT = 502           # Default Modbus TCP port

# %%
def modbus(PLC_IP, PLC_PORT):

    # Create Modbus client
    client = ModbusTcpClient(PLC_IP, port=PLC_PORT)

    # Connect to the PLC
    if client.connect():
        print("Connection successful")
    else:
        print("Failed to connect to PLC")
    return client

# %%
def PLC(client, coil_address,value):
    write_result = client.write_coil(address=coil_address, value=value)  # Write 'True' to turn ON
    if write_result.isError():
        print("Write Error:", write_result)

# %%
def crop_image(frame, x, y, w, h):
    return frame[y:y+h, x:x+w]

# %%
def measure_brightness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
    brightness = np.mean(gray)
    return brightness

# %%
def measure_edge_richness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    edges = cv2.Canny(gray, 100, 200)  # Apply Canny edge detection
    edge_richness = np.sum(edges)  # Sum of edge pixel intensities
    return edge_richness

# %%
def select_best_frame(frame_buffer, x, y, w, h, max_brightness):

    best_frame = None
    highest_brightness = 0
    highest_edge_richness = 400000

    for frame in frame_buffer:

        #Crop
        cropped_frame = crop_image(frame, x, y, w, h)

        # Measure brightness
        brightness = measure_brightness(cropped_frame)

        if brightness > max_brightness :
            # Update the best frame if this one is better
            if brightness > highest_brightness:
                highest_brightness = brightness
                best_frame = frame  # Save the frame as the best frame
        
        elif brightness > 150 and brightness < 176:
            # Apply edge detection
            edge_richness = measure_edge_richness(cropped_frame)
            # Update the best frame if this one is better
            if edge_richness > highest_edge_richness:
                highest_edge_richness = edge_richness
                best_frame = frame  # Save the cropped frame as the best frame


    return best_frame  # Returns None if no frames meet the threshold

# %%
def process_frame(frame, target_size):

    # Resize the frame to the target size
    resized_frame = cv2.resize(frame, target_size)

    # Normalize pixel values to [0, 1]
    normalized_frame = resized_frame / 255.0

    # Convert to NumPy array and add batch dimension
    frame_array = img_to_array(normalized_frame)
    frame_array = np.expand_dims(frame_array, axis=0)  # Shape: (1, height, width, channels)

    return frame_array

# %%
def predict_frame(frame, model, target_size):

    # Preprocess the frame
    frame_array = process_frame(frame, target_size)

   # Make a prediction
    prediction = model.predict(frame_array)[0][0]  # Get the confidence score
    print(f"Raw Prediction: {prediction}")

    # Interpret the prediction
    if prediction > 0.5:
        PLC(client, coil_address,False)
        return "Non-Defective", prediction       
        
    else:
        PLC(client, coil_address,True)
        return "Defective", prediction

# %%
def capture(cam, fps, frame_buffer, raw_frame_queue, max_frames, stop_event):
    
    cap = cv2.VideoCapture(cam)  # Open webcam
    cap.set(cv2.CAP_PROP_FPS, fps)  # Set the desired FPS

    if not cap.isOpened():
        print("Error: Cannot open camera.")
        return

    while not stop_event.is_set():
        ret, frame = cap.read()
        if not ret:
            print("Failed to capture frame. Exiting...")
            break

        frame_buffer.append(frame)

        # Yield the buffer when it's full
        if len(frame_buffer) == max_frames:
            raw_frame_queue.put(frame_buffer.copy())  # Add a copy of the buffer
            frame_buffer.clear()  # Clear the buffer for the next batch

    cap.release()

# %%
def selector(raw_frame_queue, processed_frame_queue, a, b, c, d, stop_event):
    while not stop_event.is_set() or not raw_frame_queue.empty():
        try:
            frame_buffer = raw_frame_queue.get(timeout=1)
        except queue.Empty:
            continue

        processed_buffer = []
        for frame in frame_buffer:
            cropped_frame = crop_image(frame, a, b, c, d)
            brightness = measure_brightness(cropped_frame)

            if not (brightness > 60 and brightness < 65):
                processed_buffer.append(frame)  # Pass frames meeting the condition

        if processed_buffer:
            try:
                processed_frame_queue.put(processed_buffer, timeout=1)
            except queue.Full:
                print("Processed frame queue is full. Dropping buffer.")

    print("Processing thread stopped.")

# %%
def runModel(model_version, processed_frame_queue, x, y, w, h, max_brightness, stop_event, target_size=(Im_Width, Im_Height)):

    # Load the model
    print("Loading model...") 
    model = load_model(model_version)
    print("Model loaded successfully.")
    
    while True:
        frame_buffer = processed_frame_queue.get()
        best_frame = select_best_frame(frame_buffer, x, y, w, h, max_brightness)
        # Process and predict
        if best_frame is not None:
            feedback, confidence = predict_frame(best_frame, model, target_size)
            

            prob = abs(round(confidence,2)- 0.5)*200
            print(f"Prediction: {feedback} (Confidence: {prob:.2f})")

            # Display feedback on the frame
            cv2.putText(best_frame, f"Prediction: {feedback}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(best_frame, f"Confidence: {prob:.0f}", (10, 60),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

            # Display the best frame
            cv2.imshow("Best Frame", best_frame)

        else:
            # Load and display the "no-bottle" image in the same window
            PLC(client, coil_address,False)
            image = cv2.imread(image_path)
            cv2.putText(image, "No Bottle!", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.imshow("Best Frame", image)

        # Exit on 'ESC' key
        if cv2.waitKey(1) & 0xFF == 27:
            #run = False
            stop_event.set()
            break

    cv2.destroyAllWindows()
    #return run

# %%
capture_thread = threading.Thread(target=capture, args=(cam, fps, frame_buffer, raw_frame_queue, max_frames, stop_event))
selector_thread = threading.Thread(target=selector, args=(raw_frame_queue, processed_frame_queue, a, b, c, d, stop_event))
runModel_thread = threading.Thread(target=runModel, args=(model_version, processed_frame_queue, x, y, w, h, max_brightness, stop_event))

# %%
if __name__ == "__main__":

    client = modbus(PLC_IP, PLC_PORT)

    # Start the threads
    capture_thread.start()
    time.sleep(0.1)
    selector_thread.start()
    time.sleep(0.1)
    runModel_thread.start()

    # Wait for threads to complete
    capture_thread.join()
    selector_thread.join()
    #frame_queue.join()
    runModel_thread.join()
# Out:
# Connection successful
# Loading model...
# Model loaded successfully.
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 772ms/step
# Raw Prediction: 0.3686981797218323
# Output Y0 turned ON (Coil 1536)
# Prediction: Defective (Confidence: 26.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.876598060131073
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 76.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9969218373298645
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9913257956504822
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 98.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9540789723396301
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 90.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Raw Prediction: 0.9942866563796997
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 98.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Raw Prediction: 0.9992373585700989
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# Output Y0 turned ON (Coil 1536)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Raw Prediction: 0.9998655915260315
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.999646008014679
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9992256164550781
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.999695897102356
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996625781059265
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9996082186698914
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9997247457504272
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996952414512634
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.999640166759491
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996216297149658
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9996760487556458
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9995570182800293
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.999701201915741
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996961951255798
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9996837377548218
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.999683141708374
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996960163116455
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9997051954269409
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996870756149292
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.999624490737915
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9996330142021179
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996654987335205
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9995885491371155
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9996070861816406
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996806979179382
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996839761734009
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996106028556824
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9997116327285767
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9995749592781067
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996346235275269
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996082186698914
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996433258056641
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9995731115341187
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996517896652222
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996417164802551
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996215105056763
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.999645471572876
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9995675683021545
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996181130409241
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9995962977409363
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9995620846748352
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9995397925376892
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996473789215088
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.999666154384613
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996745586395264
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996373057365417
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996702671051025
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996723532676697
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996773600578308
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9996232986450195
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996646642684937
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9996925592422485
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996680021286011
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9997068047523499
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9996746778488159
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996721744537354
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.9996145367622375
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996833801269531
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996073246002197
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996025562286377
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.999472439289093
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9997266530990601
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996421337127686
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996113777160645
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9997173547744751
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996525049209595
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9997013211250305
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996000528335571
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9996209740638733
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9995982646942139
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996272325515747
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996217489242554
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9996204376220703
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.9997134804725647
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9996874332427979
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9995815753936768
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9996545314788818
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9997187852859497
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9996512532234192
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9997155666351318
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.999642550945282
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.999505341053009
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.999674379825592
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.9996605515480042
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9997076988220215
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9996303915977478
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9996463656425476
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9997068047523499
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9996218085289001
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9997196197509766
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9996892213821411
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996573328971863
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9995719194412231
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9996103644371033
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996413588523865
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9997109174728394
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996809959411621
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.99972003698349
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9997198581695557
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9996611475944519
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996715188026428
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9996968507766724
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9995760917663574
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9994195699691772
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9996585845947266
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9996538162231445
# Output Y0 turned ON (Coil 1536)
# Prediction: Non-Defective (Confidence: 100.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9