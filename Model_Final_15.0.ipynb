# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import img_to_array
import threading
import queue
from pymodbus.client import ModbusTcpClient

# %%
cam = 0
fps = 240 #Maximum achivable was 163.06

model_version = "my_model_12.0.keras"
max_frames = 3  # Number of frames to evaluate

image_path = "Image0001.jpg"
frame_buffer = []
frame_queue = queue.Queue(maxsize=10)

PLC_IP = "192.168.1.111"  #PLC's IP address
PLC_PORT = 502           # Default Modbus TCP port

Im_Width = 128
Im_Height = 128

#crop
x = 220
y = 0
w = 200
h = 200

max_brightness = 100
#max_edgeRichness = 

stop_event = threading.Event()

# %%
def modbus(PLC_IP, PLC_PORT):

    # Create Modbus client
    client = ModbusTcpClient(PLC_IP, port=PLC_PORT)

    # Connect to the PLC
    if client.connect():
        print("Connection successful")
    else:
        print("Failed to connect to PLC")
    return client

# %%
def PLC(client, coil_address,value):
    write_result = client.write_coil(address=coil_address, value=value)  # Write 'True' to turn ON
    if write_result.isError():
        print("Write Error:", write_result)
    else:
        print(f"Output Y0 turned ON (Coil {coil_address})")

# %%
def crop_image(frame, x, y, w, h):
    return frame[y:y+h, x:x+w]

# %%
def measure_brightness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
    brightness = np.mean(gray)
    return brightness

# %%
def measure_edge_richness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    edges = cv2.Canny(gray, 200, 400)  # Apply Canny edge detection
    edge_richness = np.sum(edges)  # Sum of edge pixel intensities
    return edge_richness

# %%
def select_best_frame(frame_buffer, x, y, w, h, max_brightness):

    best_frame = None
    highest_brightness = 0
    highest_edge_richness = 0

    for frame in frame_buffer:

        #Crop
        cropped_frame = crop_image(frame, x, y, w, h)

        # Measure brightness
        brightness = measure_brightness(cropped_frame)

        if brightness > max_brightness :
            # Update the best frame if this one is better
            if brightness > highest_brightness:
                highest_brightness = brightness
                best_frame = frame  # Save the frame as the best frame
        
        elif brightness > 50 and brightness < 100:
            # Apply edge detection
            edge_richness = measure_edge_richness(cropped_frame)
            # Update the best frame if this one is better
            if edge_richness > highest_edge_richness:
                highest_edge_richness = edge_richness
                best_frame = frame  # Save the cropped frame as the best frame


    return best_frame  # Returns None if no frames meet the threshold

# %%
def process_frame(frame, target_size):

    # Resize the frame to the target size
    resized_frame = cv2.resize(frame, target_size)

    # Normalize pixel values to [0, 1]
    normalized_frame = resized_frame / 255.0

    # Convert to NumPy array and add batch dimension
    frame_array = img_to_array(normalized_frame)
    frame_array = np.expand_dims(frame_array, axis=0)  # Shape: (1, height, width, channels)

    return frame_array

# %%
def predict_frame(frame, model, target_size):

    # Preprocess the frame
    frame_array = process_frame(frame, target_size)

   # Make a prediction
    prediction = model.predict(frame_array)[0][0]  # Get the confidence score
    print(f"Raw Prediction: {prediction}")

    # Interpret the prediction
    if prediction > 0.5:
        PLC(client, coil_address,False)
        return "Non-Defective", prediction       
        
    else:
        PLC(client, coil_address,True)
        return "Defective", prediction

# %%
def capture(cam, fps, frame_buffer, frame_queue, max_frames, stop_event):
    
    cap = cv2.VideoCapture(cam)  # Open webcam
    cap.set(cv2.CAP_PROP_FPS, fps)  # Set the desired FPS

    while not stop_event.is_set():
        if not cap.isOpened():
            print("Error: Cannot open camera.")
            return

        while not stop_event.is_set():
            ret, frame = cap.read()
            if not ret:
                print("Failed to capture frame. Exiting...")
                break

            frame_buffer.append(frame)

            # Yield the buffer when it's full
            if len(frame_buffer) == max_frames:
                frame_queue.put(frame_buffer.copy())  # Add a copy of the buffer
                frame_buffer.clear()  # Clear the buffer for the next batch

    cap.release()

# %%
# import cv2
# import threading
# import queue
# import time

# def capture_frames(cam, fps, frame_queue, buffer_size=30):
#     """
#     Captures frames from the camera and stores them in a queue for processing.
    
#     Args:
#         cam (int): Camera index.
#         fps (int): Frames per second.
#         frame_queue (queue.Queue): Queue to store frame buffers.
#         buffer_size (int): Number of frames per buffer.
#     """
#     cap = cv2.VideoCapture(cam)  # Open webcam
#     cap.set(cv2.CAP_PROP_FPS, fps)  # Set FPS

#     if not cap.isOpened():
#         print("Error: Cannot open camera.")
#         return

#     frame_buffer = []

#     while True:
#         ret, frame = cap.read()
#         if not ret:
#             print("Failed to capture frame. Exiting...")
#             break

#         frame_buffer.append(frame)

#         # Add the buffer to the queue when full
#         if len(frame_buffer) == buffer_size:
#             frame_queue.put(frame_buffer.copy())  # Add a copy of the buffer
#             frame_buffer.clear()  # Clear the buffer for the next batch

#     cap.release()

# def process_frames(frame_queue):
#     """
#     Processes frame buffers retrieved from the queue.
    
#     Args:
#         frame_queue (queue.Queue): Queue to retrieve frame buffers from.
#     """
#     while True:
#         try:
#             # Get a buffer from the queue
#             frame_buffer = frame_queue.get(timeout=5)  # Wait for buffer (5 sec timeout)
#             print(f"Processing buffer with {len(frame_buffer)} frames")
            
#             # Simulate processing time
#             time.sleep(1)

#         except queue.Empty:
#             print("No buffers left to process. Exiting...")
#             break

# if __name__ == "__main__":
#     cam = 0  # Default camera index
#     fps = 30  # Desired FPS
#     buffer_size = 30  # Number of frames per buffer
#     frame_queue = queue.Queue(maxsize=10)  # Queue with a maximum of 10 buffers

#     # Create threads
#     capture_thread = threading.Thread(target=capture_frames, args=(cam, fps, frame_queue, buffer_size))
#     processing_thread = threading.Thread(target=process_frames, args=(frame_queue,))

#     # Start threads
#     capture_thread.start()
#     processing_thread.start()

#     # Wait for threads to complete
#     capture_thread.join()
#     processing_thread.join()

#     print("All tasks completed.")

# %%
def runModel(model_version, frame_queue, x, y, w, h, max_brightness, stop_event, target_size=(Im_Width, Im_Height)):

    # Load the model
    print("Loading model...") 
    model = load_model(model_version)
    print("Model loaded successfully.")
    
    while True:
        frame_buffer = frame_queue.get()
        best_frame = select_best_frame(frame_buffer, x, y, w, h, max_brightness)
        # Process and predict
        if best_frame is not None:
            feedback, confidence = predict_frame(best_frame, model, target_size)
            print(f"Prediction: {feedback} (Confidence: {confidence:.2f})")

            prob = abs(round(confidence,2)- 0.5)*200

            # Display feedback on the frame
            cv2.putText(best_frame, f"Prediction: {feedback}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(best_frame, f"Confidence: {prob:.0f}", (10, 60),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

            # Display the best frame
            cv2.imshow("Best Frame", best_frame)

        else:
            # Load and display the "no-bottle" image in the same window
            image = cv2.imread(image_path)
            cv2.putText(image, "No Bottle!", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.imshow("Best Frame", image)

        # Exit on 'ESC' key
        if cv2.waitKey(1) & 0xFF == 27:
            #run = False
            stop_event.set()
            break

    cv2.destroyAllWindows()

# %%
capture_thread = threading.Thread(target=capture, args=(cam, fps, frame_buffer, frame_queue, max_frames, stop_event))
runModel_thread = threading.Thread(target=runModel, args=(model_version, frame_queue, x, y, w, h, max_brightness, stop_event))

# %%
if __name__ == "__main__":

    # Start the threads
    capture_thread.start()
    runModel_thread.start()

    # Wait for threads to complete
    capture_thread.join()
    runModel_thread.join()
# Out:
# Loading model...
# Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 920ms/step
# Raw Prediction: 0.9836007952690125
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.9833984375
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9796957969665527
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9493280053138733
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9678815603256226
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9854474067687988
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.978033185005188
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9811966419219971
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9857729077339172
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9841869473457336
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.987585186958313
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9866905212402344
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9849426746368408
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9839860200881958
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.9863242506980896
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9837860465049744
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9825087785720825
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9836975932121277
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.9839544296264648
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Raw Prediction: 0.9830779433250427
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9833833575248718
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9858800768852234
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9863518476486206
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9863518476486206
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9871547222137451
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.98600172996521
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.984458327293396
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9888733625411987
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9876160025596619
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9873197078704834
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9777913689613342
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9769697189331055
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9918501377105713
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9742164015769958
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9757705926895142
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9731820225715637
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9890739321708679
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9896341562271118
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9842258095741272
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9865124225616455
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9872515201568604
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9872577786445618
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9910894632339478
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9904018044471741
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9919490814208984
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9907981157302856
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9855576157569885
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9234563112258911
# Prediction: Non-Defective (Confidence: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9150465726852417
# Prediction: Non-Defective (Confidence: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.5775033235549927
# Prediction: Non-Defective (Confidence: 0.58)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.0043370770290493965
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.6892393231391907
# Prediction: Non-Defective (Confidence: 0.69)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.6584653258323669
# Prediction: Non-Defective (Confidence: 0.66)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.06467807292938232
# Prediction: Defective (Confidence: 0.06)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.0003639503556769341
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.0011169740464538336
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.0660284236073494
# Prediction: Defective (Confidence: 0.07)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.0008878301596269011
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.018591880798339844
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.2612547278404236
# Prediction: Defective (Confidence: 0.26)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.976876437664032
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9684687256813049
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9822272658348083
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9867672324180603
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9874035120010376
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9890075922012329
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9868348240852356
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9919068813323975
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9933644533157349
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9921127557754517
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9898636937141418
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9881911873817444
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9883008003234863
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9847992658615112
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9761483669281006
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9822641015052795
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9933390021324158
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9954663515090942
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9939810633659363
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9912275671958923
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9906296133995056
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9816020131111145
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9875375628471375
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.060449302196502686
# Prediction: Defective (Confidence: 0.06)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.001657508430071175
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9200006127357483
# Prediction: Non-Defective (Confidence: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.0035318750888109207
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.14266055822372437
# Prediction: Defective (Confidence: 0.14)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.8431307673454285
# Prediction: Non-Defective (Confidence: 0.84)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.6708754301071167
# Prediction: Non-Defective (Confidence: 0.67)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9199568629264832
# Prediction: Non-Defective (Confidence: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9568891525268555
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9434652328491211
# Prediction: Non-Defective (Confidence: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9371848702430725
# Prediction: Non-Defective (Confidence: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9357962012290955
# Prediction: Non-Defective (Confidence: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.8404843807220459
# Prediction: Non-Defective (Confidence: 0.84)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9603288769721985
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.928734540939331
# Prediction: Non-Defective (Confidence: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9321157336235046
# Prediction: Non-Defective (Confidence: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.7820997834205627
# Prediction: Non-Defective (Confidence: 0.78)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9482925534248352
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9336040616035461
# Prediction: Non-Defective (Confidence: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9653978943824768
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9688664078712463
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.8676026463508606
# Prediction: Non-Defective (Confidence: 0.87)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.0012703846441581845
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.5188418626785278
# Prediction: Non-Defective (Confidence: 0.52)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.08422761410474777
# Prediction: Defective (Confidence: 0.08)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.06466197967529297
# Prediction: Defective (Confidence: 0.06)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.7156748175621033
# Prediction: Non-Defective (Confidence: 0.72)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.45572179555892944
# Prediction: Defective (Confidence: 0.46)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.20488324761390686
# Prediction: Defective (Confidence: 0.20)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.4629988670349121
# Prediction: Defective (Confidence: 0.46)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.24877138435840607
# Prediction: Defective (Confidence: 0.25)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9834363460540771
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9824397563934326
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.06779826432466507
# Prediction: Defective (Confidence: 0.07)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.15790866315364838
# Prediction: Defective (Confidence: 0.16)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.31750914454460144
# Prediction: Defective (Confidence: 0.32)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.24663175642490387
# Prediction: Defective (Confidence: 0.25)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9423947334289551
# Prediction: Non-Defective (Confidence: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9719988703727722
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9323655962944031
# Prediction: Non-Defective (Confidence: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.9178169965744019
# Prediction: Non-Defective (Confidence: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9994150400161743
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9995577931404114
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9994382262229919
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9987024068832397
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9952410459518433
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9939695596694946
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9925478100776672
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9958736300468445
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9959956407546997
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9962155222892761
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9908627271652222
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9902033805847168
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9421951174736023
# Prediction: Non-Defective (Confidence: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9744536876678467
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.8868435621261597
# Prediction: Non-Defective (Confidence: 0.89)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.17561760544776917
# Prediction: Defective (Confidence: 0.18)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.016463816165924072
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.010839850641787052
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.07289613038301468
# Prediction: Defective (Confidence: 0.07)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.7068286538124084
# Prediction: Non-Defective (Confidence: 0.71)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9166814684867859
# Prediction: Non-Defective (Confidence: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.4183589816093445
# Prediction: Defective (Confidence: 0.42)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.015727246180176735
# Prediction: Defective (Confidence: 0.02)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.0011062914272770286
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.02840949408710003
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.007772375829517841
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.02502136491239071
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.002484321128576994
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.07337144762277603
# Prediction: Defective (Confidence: 0.07)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.17218820750713348
# Prediction: Defective (Confidence: 0.17)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.0005512330099008977
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.005007703322917223
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.006428263150155544
# Prediction: Defective (Confidence: 0.01)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.028596671298146248
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.03069998510181904
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.02572980709373951
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.12488870322704315
# Prediction: Defective (Confidence: 0.12)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.05400937795639038
# Prediction: Defective (Confidence: 0.05)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.0291037205606699
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.03168589249253273
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.2956227660179138
# Prediction: Defective (Confidence: 0.30)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.4013471305370331
# Prediction: Defective (Confidence: 0.40)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.25815126299858093
# Prediction: Defective (Confidence: 0.26)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.3717980980873108
# Prediction: Defective (Confidence: 0.37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.7647596001625061
# Prediction: Non-Defective (Confidence: 0.76)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.6893039345741272
# Prediction: Non-Defective (Confidence: 0.69)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.48596131801605225
# Prediction: Defective (Confidence: 0.49)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.7447937726974487
# Prediction: Non-Defective (Confidence: 0.74)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9136645197868347
# Prediction: Non-Defective (Confidence: 0.91)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9547604918479919
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.8232353925704956
# Prediction: Non-Defective (Confidence: 0.82)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9440293312072754
# Prediction: Non-Defective (Confidence: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9679728746414185
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9723283052444458
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.8186542987823486
# Prediction: Non-Defective (Confidence: 0.82)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.8522852063179016
# Prediction: Non-Defective (Confidence: 0.85)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.30531710386276245
# Prediction: Defective (Confidence: 0.31)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.927884042263031
# Prediction: Non-Defective (Confidence: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9449182152748108
# Prediction: Non-Defective (Confidence: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9572269916534424
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9758504033088684
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.8612648844718933
# Prediction: Non-Defective (Confidence: 0.86)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9134016036987305
# Prediction: Non-Defective (Confidence: 0.91)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.949770450592041
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9518024325370789
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9536821246147156
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9536944627761841
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.8699578642845154
# Prediction: Non-Defective (Confidence: 0.87)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.41480007767677307
# Prediction: Defective (Confidence: 0.41)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.6458806395530701
# Prediction: Non-Defective (Confidence: 0.65)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9306821823120117
# Prediction: Non-Defective (Confidence: 0.93)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.6059485673904419
# Prediction: Non-Defective (Confidence: 0.61)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.17475128173828125
# Prediction: Defective (Confidence: 0.17)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.3687060475349426
# Prediction: Defective (Confidence: 0.37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.38358065485954285
# Prediction: Defective (Confidence: 0.38)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.0022928393445909023
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 2.919215603469638e-06
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.00019339709251653403
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.06557144224643707
# Prediction: Defective (Confidence: 0.07)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.00037569625419564545
# Prediction: Defective (Confidence: 0.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.032723866403102875
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.08797594159841537
# Prediction: Defective (Confidence: 0.09)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.47871100902557373
# Prediction: Defective (Confidence: 0.48)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.410675585269928
# Prediction: Defective (Confidence: 0.41)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.14584288001060486
# Prediction: Defective (Confidence: 0.15)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.2717517614364624
# Prediction: Defective (Confidence: 0.27)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.08054095506668091
# Prediction: Defective (Confidence: 0.08)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.032795846462249756
# Prediction: Defective (Confidence: 0.03)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.09962470829486847
# Prediction: Defective (Confidence: 0.10)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.08924183994531631
# Prediction: Defective (Confidence: 0.09)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.09965340048074722
# Prediction: Defective (Confidence: 0.10)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Raw Prediction: 0.22303195297718048
# Prediction: Defective (Confidence: 0.22)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.6543454527854919
# Prediction: Non-Defective (Confidence: 0.65)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.5966057181358337
# Prediction: Non-Defective (Confidence: 0.60)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.7846986055374146
# Prediction: Non-Defective (Confidence: 0.78)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.7988340854644775
# Prediction: Non-Defective (Confidence: 0.80)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9225666522979736
# Prediction: Non-Defective (Confidence: 0.92)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9584381580352783
# Prediction: Non-Defective (Confidence: 0.96)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9801384210586548
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9680808186531067
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9862557053565979
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9813344478607178
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9504066109657288
# Prediction: Non-Defective (Confidence: 0.95)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9447408318519592
# Prediction: Non-Defective (Confidence: 0.94)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9702571034431458
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.972727358341217
# Prediction: Non-Defective (Confidence: 0.97)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9793064594268799
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9856789708137512
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9884228110313416
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9803748726844788
# Prediction: Non-Defective (Confidence: 0.98)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9903689026832581
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9932250380516052
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.995863676071167
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.995182454586029
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9953042268753052
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9951672554016113
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Raw Prediction: 0.9935611486434937
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9947044253349304
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9931555390357971
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9953049421310425
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9939956068992615
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9943141341209412
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9932565689086914
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9927799105644226
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9927914142608643
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Raw Prediction: 0.9937611222267151
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Raw Prediction: 0.9944851994514465
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.993553876876831
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9934288859367371
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.9945935606956482
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Raw Prediction: 0.9962080717086792
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Raw Prediction: 0.9943945407867432
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9948567152023315
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9948221445083618
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9920337796211243
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.991658627986908
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9915265440940857
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9875494241714478
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9860534071922302
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9903839826583862
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.991999626159668
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Raw Prediction: 0.9866167306900024
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9871359467506409
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Raw Prediction: 0.9863930344581604
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Raw Prediction: 0.9907743334770203
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9952884912490845
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Raw Prediction: 0.9918686151504517
# Prediction: Non-Defective (Confidence: 0.99)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Raw Prediction: 0.9954220652580261
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Raw Prediction: 0.9967683553695679
# Prediction: Non-Defective (Confidence: 1.00)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Exception in thread Thread-8 (runModel):
# Traceback (most recent call last):
#   File "c:\Users\malin\AppData\Local\Programs\Python\Python310\lib\threading.py", line 1009, in _bootstrap_inner
#     self.run()
#   File "C:\Users\malin\AppData\Roaming\Python\Python310\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\malin\AppData\Local\Programs\Python\Python310\lib\threading.py", line 946, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\malin\AppData\Local\Temp\ipykernel_3112\758432939.py", line 41, in runModel
# NameError: name 'run' is not defined
# Raw Prediction: 0.997357189655304
# Prediction: Non-Defective (Confidence: 1.00)
